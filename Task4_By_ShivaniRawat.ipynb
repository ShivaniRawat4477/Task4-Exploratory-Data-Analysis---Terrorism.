# %% [markdown]
# # GRIP OCT 2022

# %% [markdown]
# # The Sparks Foundation: Orientation for Graduate Rotational Internship Program

# %% [markdown]
# ### Data Science and Business Analytics:

# %% [markdown]
# # Task4: Exploratory Data Analysis - Terrorism.

# %% [markdown]
# ## Tasks: 1.Perform Exploratory Data Analysis on dataset 'Global Terrorism'.
# ## 2. As a Security/Defense Analyst, try to find out the hot zone of terrorism.
# ## 3. What all security issues and insights you can derive by EDA?
#
# ### Data Source:  https://bit.ly/2TK5Xn5

# %% [markdown]
# # Author: Shivani Rawat

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the data

df = pd.read_csv(r'C:\Users\sania\Desktop\globalterrorismdb.csv', encoding = 'latin1')
df.head()
# Out:
# C:\Users\sania\AppData\Local\Temp\ipykernel_16436\3095097478.py:3: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\sania\Desktop\globalterrorismdb.csv', encoding = 'latin1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Check the shape of dataset
df.shape
# Out:
# (181691, 135)

# %% [markdown]
# ## 1.Perform Exploratory Data Analysis on dataset 'Global Terrorism'.

# %%
df.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
# To check missing values/ Null values

df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# To check duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Cleaning

# %%
#To print all the columns name
for i in df.columns:
    print(i)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %% [markdown]
# As we can see we are having alot of columns but few of them has valueable information. So now we'll extract only important columns with valueable information.

# %%
data = df[['eventid','iyear','imonth','iday','country_txt','region_txt','provstate','city','latitude','longitude','specificity','location','summary','attacktype1_txt','targtype1_txt','natlty1_txt','gname','motive','weaptype1_txt','nkill','nwound','propextent_txt','dbsource']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 23 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   eventid          181691 non-null  int64
#  1   iyear            181691 non-null  int64
#  2   imonth           181691 non-null  int64
#  3   iday             181691 non-null  int64
#  4   country_txt      181691 non-null  object
#  5   region_txt       181691 non-null  object
#  6   provstate        181270 non-null  object
#  7   city             181257 non-null  object
#  8   latitude         177135 non-null  float64
#  9   longitude        177134 non-null  float64
#  10  specificity      181685 non-null  float64
#  11  location         55495 non-null   object
#  12  summary          115562 non-null  object
#  13  attacktype1_txt  181691 non-null  object
#  14  targtype1_txt    181691 non-null  object
#  15  natlty1_txt      180132 non-null  object
# ...

# %%
# Lets Rename the columns

df = data.rename(columns = {'iyear':'year','imonth':'month','iday':'day','country_txt':'country', 'region_txt':'region', 'provstate':'province','attacktype1_txt':'attack_type','targtype1_txt':'target_type','natlty1_txt':'nationality','weaptype1_txt':'weapon_type'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   eventid         181691 non-null  int64
#  1   year            181691 non-null  int64
#  2   month           181691 non-null  int64
#  3   day             181691 non-null  int64
#  4   country         181691 non-null  object
#  5   region          181691 non-null  object
#  6   province        181270 non-null  object
#  7   city            181257 non-null  object
#  8   latitude        177135 non-null  float64
#  9   longitude       177134 non-null  float64
#  10  specificity     181685 non-null  float64
#  11  location        55495 non-null   object
#  12  summary         115562 non-null  object
#  13  attack_type     181691 non-null  object
#  14  target_type     181691 non-null  object
#  15  nationality     180132 non-null  object
# ...

# %%
df.shape
# Out:
# (181691, 23)

# %%
# Lets check null values

df.isnull().sum()
# Out:
# eventid                0
# year                   0
# month                  0
# day                    0
# country                0
# region                 0
# province             421
# city                 434
# latitude            4556
# longitude           4557
# specificity            6
# location          126196
# summary            66129
# attack_type            0
# target_type            0
# nationality         1559
# gname                  0
# motive            131130
# weapon_type            0
# nkill              10313
# nwound             16311
# propextent_txt    117626
# dbsource               0
# dtype: int64

# %% [markdown]
# As we can see our data has lots of null values, so now we are going to replace the null values with zero.

# %%
df['province'].fillna((0),inplace = True)
df['city'].fillna((0),inplace = True)
df['latitude'].fillna((0),inplace = True)
df['longitude'].fillna((0),inplace = True)
df['specificity'].fillna((0),inplace = True)
df['location'].fillna((0),inplace = True)
df['summary'].fillna((0),inplace = True)
df['nationality'].fillna((0),inplace = True)
df['motive'].fillna((0),inplace = True)
df['nkill'].fillna((0),inplace = True)
df['nwound'].fillna((0),inplace = True)
df['propextent_txt'].fillna((0),inplace = True)

# %%
df.isnull().sum()
# Out:
# eventid           0
# year              0
# month             0
# day               0
# country           0
# region            0
# province          0
# city              0
# latitude          0
# longitude         0
# specificity       0
# location          0
# summary           0
# attack_type       0
# target_type       0
# nationality       0
# gname             0
# motive            0
# weapon_type       0
# nkill             0
# nwound            0
# propextent_txt    0
# dbsource          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# As we can see now our data doesn't have any null or duplicates values. Now our data is ready for anaysis.

# %%
df.head()
# Out:
#         eventid  year  month  day             country  \
# 0  197000000001  1970      7    2  Dominican Republic
# 1  197000000002  1970      0    0              Mexico
# 2  197001000001  1970      1    0         Philippines
# 3  197001000002  1970      1    0              Greece
# 4  197001000003  1970      1    0               Japan
#
#                         region province           city   latitude   longitude  \
# 0  Central America & Caribbean        0  Santo Domingo  18.456792  -69.951164
# 1                North America  Federal    Mexico city  19.371887  -99.086624
# 2               Southeast Asia   Tarlac        Unknown  15.478598  120.599741
# 3               Western Europe   Attica         Athens  37.997490   23.762728
# 4                    East Asia  Fukouka        Fukouka  33.580412  130.396361
#
#    ...                     attack_type                  target_type  \
# 0  ...                   Assassination  Private Citizens & Property
# ...

# %%
df.tail()
# Out:
#              eventid  year  month  day      country  \
# 181686  201712310022  2017     12   31      Somalia
# 181687  201712310029  2017     12   31        Syria
# 181688  201712310030  2017     12   31  Philippines
# 181689  201712310031  2017     12   31        India
# 181690  201712310032  2017     12   31  Philippines
#
#                             region         province           city   latitude  \
# 181686          Sub-Saharan Africa  Middle Shebelle  Ceelka Geelow   2.359673
# 181687  Middle East & North Africa         Lattakia         Jableh  35.407278
# 181688              Southeast Asia      Maguindanao       Kubentog   6.900742
# 181689                  South Asia          Manipur         Imphal  24.798346
# 181690              Southeast Asia      Maguindanao  Cotabato City   7.209594
#
#          longitude  ...                     attack_type  \
# 181686   45.385034  ...                   Armed Assault
# 181687   35.942679  ...               Bombing/Explosion
# ...

# %%
df.describe()
# Out:
#             eventid           year          month            day  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             latitude     longitude    specificity          nkill  \
# count  181691.000000  1.816910e+05  181691.000000  181691.000000
# mean       22.909109 -4.471911e+02       1.451404       2.266860
# std        18.699442  2.021946e+05       0.995448      11.227057
# min       -53.154613 -8.618590e+07       0.000000       0.000000
# ...

# %% [markdown]
# ## 2. As a Security/Defense Analyst, try to find out the hot zone of terrorism.

# %%
# Yearly total no. of attacks

yearly_attacks = df['year'].value_counts(dropna = False).sort_index()
yearly_attacks
# Out:
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: year, dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Yearly total no. of attacks

# %%
yearly_attacks.plot(kind = 'bar',color = 'red', figsize = (18,10))
plt.xlabel('Attack Year')
plt.ylabel('No. of Attacks each year')
plt.title('Total Attacks per year')
plt.show()

# %%
yearly_attacks.describe()
# Out:
# count       47.000000
# mean      3865.765957
# std       3836.943826
# min        471.000000
# 25%       1364.000000
# 50%       2870.000000
# 75%       4503.500000
# max      16903.000000
# Name: year, dtype: float64

# %% [markdown]
# ### Maximum attacks happens in 2014 i.e. 16903.

# %% [markdown]
# # Terrorist Activities by Region in each Year through Area Plot

# %%
Reg_wise_attacks = pd.crosstab(df.year, df.region)
Reg_wise_attacks
# Out:
# region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
# 1975                        0                            9             0
# 1976                        0                           45             0
# 1977                        0                           24             0
# 1978                        2                          199             0
# 1979                        2                          609             0
# 1980                        7                         1070             0
# 1981                        3                         1148             0
# ...

# %%
Reg_wise_attacks.plot(kind = "area", figsize = (15,6), stacked = False, alpha = 0.5)
plt.title("Region wise Attack in each year")
plt.xlabel("Year")
plt.ylabel("Number of Attacks")
plt.show()

# %%
Reg_wise_attacks.describe()
# Out:
# region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# count               47.000000                    47.000000     47.000000
# mean                 6.000000                   220.085106     11.978723
# std                  6.570686                   334.197340     18.292894
# min                  0.000000                     0.000000      0.000000
# 25%                  1.000000                     4.500000      0.000000
# 50%                  4.000000                    11.000000      6.000000
# 75%                  9.500000                   354.500000     14.500000
# max                 29.000000                  1148.000000     77.000000
#
# region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# count   47.000000       47.000000                   47.000000      47.000000
# mean    17.063830      109.446809                 1073.914894      73.531915
# std     22.102925      174.970284                 1667.022884      75.227438
# ...

# %% [markdown]
# ### So Maximum attacks happens in "Middle East & North Africa" region.

# %% [markdown]
# # Top Countries affected by Terror attacks

# %%
top_countries = df.country.value_counts().head(20)
top_countries
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Sri Lanka          3022
# United States      2836
# Algeria            2743
# France             2693
# Egypt              2479
# Name: country, dtype: int64

# %%
top_countries.plot(kind = "bar", color = "darkblue", figsize = (20,10))
plt.title("Top Countries Affected")
plt.xlabel("Countries")
plt.ylabel("count of attacks")
plt.show()

# %% [markdown]
# ### So maximum attacks happens in "Iraq" with count of : 24636

# %% [markdown]
# # Terrorist organizations which are responsible for attacks.

# %%
terror_org = df.gname.value_counts()[1:20]
terror_org
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Basque Fatherland and Freedom (ETA)                 2024
# Communist Party of India - Maoist (CPI-Maoist)      1878
# Maoists                                             1630
# Liberation Tigers of Tamil Eelam (LTTE)             1606
# National Liberation Army of Colombia (ELN)          1561
# Tehrik-i-Taliban Pakistan (TTP)                     1351
# ...

# %%
terror_org.plot(kind = "bar", color = "darkcyan", figsize = (30,20))
plt.title("Top Terrorist organizations with number of terror attacks")
plt.xlabel("Terrorist organizations")
plt.ylabel("Number of attacks")
plt.show()

# %% [markdown]
# ### The most number of attacks were done by "Taliban" with 7478 attacks.

# %% [markdown]
# # Total Number of people killed in terror attack.

# %%
#Region wise killed

Reg_wise_kill = df[["region", "nkill"]].groupby("region").sum()
Reg_wise_kill
# Out:
#                               nkill
# region
# Australasia & Oceania           150
# Central America & Caribbean   28708
# Central Asia                   1000
# East Asia                      1152
# Eastern Europe                 7415
# Middle East & North Africa   137642
# North America                  4916
# South America                 28849
# South Asia                   101319
# Southeast Asia                15637
# Sub-Saharan Africa            78386
# Western Europe                 6694

# %%
Reg_wise_kill.describe()
# Out:
#                nkill
# count      12.000000
# mean    34322.333333
# std     45970.536504
# min       150.000000
# 25%      3975.000000
# 50%     11526.000000
# 75%     41233.250000
# max    137642.000000

# %%
#Plot Killed Data

Reg_wise_kill.plot(kind = "bar", color = "crimson", figsize = (20,10))
plt.title("Region wise Total killed")
plt.xlabel("Region")
plt.ylabel("Number of Kills")
plt.show()

# %% [markdown]
# ### The most number of kills were in Middle East & North Africa with kills: 137642

# %%
# Country wise total number of kills happens.

total_kill = df.loc[:,'nkill']
print('Number of people killed by terror attack:',int(sum(total_kill)))
# Out:
# Number of people killed by terror attack: 411868

# %%
#Countrywise Killed

Country_wise_Kill = df[["country", "nkill"]].groupby("country").sum().sort_values(by ='nkill', ascending =False).head(10)
Country_wise_Kill
# Out:
#              nkill
# country
# Iraq         78589
# Afghanistan  39384
# Pakistan     23822
# Nigeria      22682
# India        19341
# Sri Lanka    15530
# Syria        15229
# Colombia     14698
# Peru         12771
# El Salvador  12053

# %%
Country_wise_Kill.describe()
# Out:
#              nkill
# count     10.00000
# mean   25409.90000
# std    20342.19228
# min    12053.00000
# 25%    14830.75000
# 50%    17435.50000
# 75%    23537.00000
# max    78589.00000

# %%
#Plot Killed Data

Country_wise_Kill.plot(kind = "bar", color = "olive", figsize = (20,10))
plt.title("Number of killed per country")
plt.xlabel("Country")
plt.ylabel("Total killed")
plt.show()

# %% [markdown]
# ### Maximum killing happens in "Iraq" i.e.: 78589

# %%
#City wise Killed

City_wise_Kill = df["city"].value_counts()[1:21]
City_wise_Kill
# Out:
# Baghdad           7589
# Karachi           2652
# Lima              2359
# Mosul             2265
# Belfast           2171
# Santiago          1621
# Mogadishu         1581
# San Salvador      1558
# Istanbul          1048
# Athens            1019
# Bogota             984
# Kirkuk             925
# Beirut             918
# Medellin           848
# Benghazi           840
# Peshawar           819
# Quetta             803
# Guatemala City     755
# Baqubah            745
# Kabul              738
# Name: city, dtype: int64

# %%
City_wise_Kill.describe()
# Out:
# count      20.0000
# mean     1611.9000
# std      1536.1905
# min       738.0000
# 25%       834.7500
# 50%      1001.5000
# 75%      1758.5000
# max      7589.0000
# Name: city, dtype: float64

# %%
#Plot Killed Data

City_wise_Kill.plot(kind = "bar", color = "darkgreen", figsize = (20,10))
plt.title("City wise Total killed")
plt.xlabel("City")
plt.ylabel("Number of Killed")
plt.show()

# %% [markdown]
# ### The most number of kills were in Baghdad with kills: 7589.

# %% [markdown]
# # Total Number of people Wounded in terror attack.

# %%
total_wounded = df.loc[:,'nwound']
print('Number of people wounded by terror attack:',int(sum(total_wounded)))
# Out:
# Number of people wounded by terror attack: 523868

# %%
#Countrywise Killed

Country_wise_wounded = df[["country", "nwound"]].groupby("country").sum().sort_values(by ='nwound', ascending =False).head(10)
Country_wise_wounded
# Out:
#                nwound
# country
# Iraq           134690
# Afghanistan     44277
# Pakistan        42038
# India           28980
# United States   20702
# Sri Lanka       15561
# Syria           14109
# Philippines     13367
# Lebanon         10904
# Colombia        10328

# %%
Country_wise_wounded.describe()
# Out:
#               nwound
# count      10.000000
# mean    33495.600000
# std     37658.337389
# min     10328.000000
# 25%     13552.500000
# 50%     18131.500000
# 75%     38773.500000
# max    134690.000000

# %%
# Plot of County wise Killed Data

Country_wise_wounded.plot(kind = "bar", color = "lightcoral", figsize = (20,10))
plt.title("Number of wounded per country")
plt.xlabel("Country")
plt.ylabel("Total wounded")
plt.show()

# %% [markdown]
# ### Maximum wounded in "Iraq" i.e.:  134690

# %% [markdown]
# # Top countries with maximum casualities.

# %%
df['nwound'] = df['nwound'].fillna(0).astype(int)
df['nkill'] = df['nkill'].fillna(0).astype(int)
df['casualities'] = df['nkill'] + df['nwound']

# %%
Country_wise_casuality = df[["country", "casualities"]].groupby("country").sum().sort_values(by ='casualities', ascending =False).head(10)
Country_wise_casuality
# Out:
#                casualities
# country
# Iraq                213279
# Afghanistan          83661
# Pakistan             65860
# India                48321
# Nigeria              32920
# Sri Lanka            31091
# Syria                29338
# Colombia             25026
# United States        24473
# Philippines          22926

# %%
#Plot Killed Data

Country_wise_casuality.plot(kind = "bar", color = "greenyellow", figsize = (20,10))
plt.title("Number of casuality per country")
plt.xlabel("Country")
plt.ylabel("Total casuality")
plt.show()

# %% [markdown]
# ### Maximum casualities happen in "Iraq" with the number of count 213279.

# %% [markdown]
# #  Types of attacks which made these deaths

# %%
# Let's look at what types of attacks these deaths were made of.
attacks = df.loc[:,'attack_type']
# attackData
typeKillData = pd.concat([attacks, total_kill], axis=1)

# %%
typeKillData.head()
# Out:
#                       attack_type  nkill
# 0                   Assassination      1
# 1     Hostage Taking (Kidnapping)      0
# 2                   Assassination      1
# 3               Bombing/Explosion      0
# 4  Facility/Infrastructure Attack      0

# %%
typeKillFormatData = typeKillData.pivot_table(columns='attack_type', values='nkill', aggfunc='sum')
typeKillFormatData
# Out:
# attack_type  Armed Assault  Assassination  Bombing/Explosion  \
# nkill               160297          24920             157321
#
# attack_type  Facility/Infrastructure Attack  Hijacking  \
# nkill                                  3642       3718
#
# attack_type  Hostage Taking (Barricade Incident)  Hostage Taking (Kidnapping)  \
# nkill                                       4478                        24231
#
# attack_type  Unarmed Assault  Unknown
# nkill                    880    32381

# %%
labels = typeKillFormatData.columns.tolist()
index = np.arange(len(labels))
transpoze = typeKillFormatData.T
values = transpoze.values.tolist()
values = values[:50]
values = [int(i[0]) for i in values] 
fig, ax = plt.subplots(figsize=(20, 20), subplot_kw=dict(aspect="equal"))
plt.pie(values, startangle=90, autopct='%.2f%%')
plt.title('Types of terrorist attacks that cause deaths')
plt.legend(labels, loc='upper right', bbox_to_anchor = (1.3, 0.9), fontsize=15) # location legend
plt.show()

# %% [markdown]
# ### Armed assault and bombing/explosion are seen to be the cause of maximum number of the deaths in these attacks.  These are the reason for around 77% deaths.

# %% [markdown]
# # Targets of Attacks

# %%
#Target Type wise Attacks

Target_wise_Attack = df["target_type"].value_counts()
Target_wise_Attack
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: target_type, dtype: int64

# %%
Target_wise_Attack.describe()
# Out:
# count       22.000000
# mean      8258.681818
# std      11650.926574
# min        137.000000
# 25%        979.750000
# 50%       3306.000000
# 75%       6605.000000
# max      43511.000000
# Name: target_type, dtype: float64

# %%
#Plot Attack Data

Target_wise_Attack.plot(kind = "bar", color = "orange", figsize = (20,10))
plt.title("Attacks per Target Type")
plt.xlabel("Target Type")
plt.ylabel("Number of Attacks")
plt.show()

# %% [markdown]
# ### The most number of attacks were on Private Property and Citizens with attacks: 43511.

# %% [markdown]
# # #Terrorist Group and Country wise Attacks

# %%
T_Attack = df[["gname", "country"]].value_counts().drop("Unknown").head(20)
T_Attack
# Out:
# C:\Users\sania\AppData\Local\Temp\ipykernel_16436\1647120527.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   T_Attack = df[["gname", "country"]].value_counts().drop("Unknown").head(20)
# gname                                             country
# Taliban                                           Afghanistan       7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq              4797
# Shining Path (SL)                                 Peru              4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador       3330
# Al-Shabaab                                        Somalia           2867
# New People's Army (NPA)                           Philippines       2770
# Irish Republican Army (IRA)                       United Kingdom    2575
# Revolutionary Armed Forces of Colombia (FARC)     Colombia          2468
# Kurdistan Workers' Party (PKK)                    Turkey            2109
# ...

# %%
T_Attack.describe()
# Out:
# count      20.000000
# mean     2415.250000
# std      1620.937964
# min       829.000000
# 25%      1380.750000
# 50%      2031.000000
# 75%      2794.250000
# max      7423.000000
# dtype: float64

# %%
#Plot of Attack Data

T_Attack.plot(kind = "bar", color = "purple", figsize = (20,10))
plt.title("Countries Attacked by Terrorist Group")
plt.xlabel("Terrorist Group, Country")
plt.xticks()
plt.ylabel("Numer of Attacks")
plt.show()

# %% [markdown]
# ### The most number of attacks were done by Taliban in Afghanistan with attacks: 7423.

# %% [markdown]
# # Humanity Affected World-Wide by Attacks.

# %%
#Casualty

Total_cas = df.loc[:, "casualities"].sum()

print("Total number of Casualties accross the world from 1970 to 2020 : ",Total_cas)
# Out:
# Total number of Casualties accross the world from 1970 to 2020 :  935736

# %%
#Killed

Total_Kill = df.loc[:, "nkill"].sum()

print("Total number of Killed accross the world from 1970 to 2020 : ", Total_Kill)
# Out:
# Total number of Killed accross the world from 1970 to 2020 :  411868

# %%
#Wounded

Total_Wound = df.loc[:, "nwound"].sum()

print("Total number of Wounded accross the world from 1970 to 2020 : ", Total_Wound)
# Out:
# Total number of Wounded accross the world from 1970 to 2020 :  523868

# %% [markdown]
# # Conclusion:

# %%
print("Country with the most attacks:",df['country'].value_counts().idxmax())
print("City with the most attacks:",df['city'].value_counts().index[1]) #as first entry is 'unknown'
print("Region with the most attacks:",df['region'].value_counts().idxmax())
print("Year with the most attacks:",df['year'].value_counts().idxmax())
print("Month with the most attacks:",df['month'].value_counts().idxmax())
print("Group with the most attacks:",df['gname'].value_counts().index[1])
print("Most Attack Types:",df['attack_type'].value_counts().idxmax())
# Out:
# Country with the most attacks: Iraq
# City with the most attacks: Baghdad
# Region with the most attacks: Middle East & North Africa
# Year with the most attacks: 2014
# Month with the most attacks: 5
# Group with the most attacks: Taliban
# Most Attack Types: Bombing/Explosion

# %% [markdown]
# # The Middle East and North Africa are seen to be the places of serious terrorist attacks.
# # Iraq is the country which has faced the most terror attacks.
# # "Taliban" is the most responsible group for all these attacks.
# # Bombing/Explosion is the attacks type which happens most during these terrorist attacks.
